# %%
import pandas as pd
edata = pd.read_csv("e-stat0000030001.csv")
pd.read_csv("e-stat0000030001.csv")
# Out:
#      男女Ａ030001 時間軸(年次) 全域・集中の別030002 全国都道府県030001 年齢５歳階級Ａ030002      VALUE
# 0         男女総数   1980年            全域           全国            総数  117060396
# 1         男女総数   1980年            全域         全国市部            総数   89187409
# 2         男女総数   1980年            全域         全国郡部            総数   27872987
# 3         男女総数   1980年            全域          北海道            総数    5575989
# 4         男女総数   1980年            全域          青森県            総数    1523907
# 5         男女総数   1980年            全域          岩手県            総数    1421927
# 6         男女総数   1980年            全域          宮城県            総数    2082320
# 7         男女総数   1980年            全域          秋田県            総数    1256745
# 8         男女総数   1980年            全域          山形県            総数    1251917
# 9         男女総数   1980年            全域          福島県            総数    2035272
# 10        男女総数   1980年            全域          茨城県            総数    2558007
# ...
